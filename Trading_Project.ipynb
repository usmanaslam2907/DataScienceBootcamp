# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Trading.csv")
data.head()
# Out:
#          id  last_price                  created_at        f1     f2    f3  \
# 0  55466910     43138.2  2023-12-27 12:47:41.916971  0.000463  15139 -43.1
# 1  55466909     43138.2  2023-12-27 12:47:40.693372  0.000463  15140 -43.1
# 2  55466908     43138.2  2023-12-27 12:47:39.968797  0.000463  15141 -37.4
# 3  55466907     43138.2  2023-12-27 12:47:38.919784  0.000463  15142 -37.4
# 4  55466906     43132.6  2023-12-27 12:47:37.881533  0.000463  15143 -39.6
#
#      f4   f5   f6   f7  ...   f152   f153   f154   f155   f156   f157   f158  \
# 0  43.0 -0.1 -4.8 -5.1  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2  695.2
# 1  43.0 -0.1 -4.7 -5.1  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2  695.2
# 2  43.0  5.6 -1.9 -0.6  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2  695.2
# 3  37.4  0.0 -3.7 -6.2  ...  695.2 -123.8  695.2 -123.8 -123.8  695.2  695.2
# 4  36.5 -3.1 -3.7 -9.4  ...  689.6 -129.4  689.6 -129.4 -129.4  689.6  689.6
#
#     f159   f160   f161
# 0 -123.8 -123.8  695.2
# ...

# %%
data.describe()
# Out:
#                  id    last_price            f1           f2            f3  \
# count  1.000000e+04  10000.000000  10000.000000  10000.00000  10000.000000
# mean   5.546190e+07  42938.580560      0.000414  20149.80990    -40.236010
# std    2.890879e+03    205.486455      0.000018   2897.95985      7.212493
# min    5.545690e+07  42659.500000      0.000397  15139.00000    -57.800000
# 25%    5.545940e+07  42747.400000      0.000400  17642.00000    -46.000000
# 50%    5.546190e+07  42835.850000      0.000408  20146.00000    -38.200000
# 75%    5.546441e+07  43145.225000      0.000417  22652.25000    -34.500000
# max    5.546691e+07  43262.000000      0.000463  25196.00000    -22.100000
#
#                  f4            f5            f6            f7           f8  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.00000
# mean      42.252370      2.016360      0.523120      1.103560      2.29049
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Columns: 164 entries, id to f161
# dtypes: float64(136), int64(27), object(1)
# memory usage: 12.5+ MB

# %%
data.dtypes
# Out:
# id              int64
# last_price    float64
# created_at     object
# f1            float64
# f2              int64
#                ...
# f157          float64
# f158          float64
# f159          float64
# f160          float64
# f161          float64
# Length: 164, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Columns: 164 entries, id to f161
# dtypes: float64(136), int64(27), object(1)
# memory usage: 12.5+ MB

# %%
data.shape
# Out:
# (10000, 164)

# %%
object_data=data.select_dtypes(include="object")
object_data.head()
# Out:
#                    created_at
# 0  2023-12-27 12:47:41.916971
# 1  2023-12-27 12:47:40.693372
# 2  2023-12-27 12:47:39.968797
# 3  2023-12-27 12:47:38.919784
# 4  2023-12-27 12:47:37.881533

# %%
d=data.drop("created_at",axis=1)
filled_data=d.fillna(d.mean())

# %%
filled_data.isnull().sum()
# Out:
# id            0
# last_price    0
# f1            0
# f2            0
# f3            0
#              ..
# f157          0
# f158          0
# f159          0
# f160          0
# f161          0
# Length: 163, dtype: int64

# %%
correlations=filled_data.corr()
print(correlations)
# Out:
#                   id  last_price        f1        f2        f3        f4  \
# id          1.000000    0.870170  0.715610 -0.999994 -0.832428  0.661117
# last_price  0.870170    1.000000  0.543172 -0.869881 -0.747808  0.628199
# f1          0.715610    0.543172  1.000000 -0.714104 -0.661259  0.476699
# f2         -0.999994   -0.869881 -0.714104  1.000000  0.832001 -0.660871
# f3         -0.832428   -0.747808 -0.661259  0.832001  1.000000 -0.822284
# ...              ...         ...       ...       ...       ...       ...
# f157        0.794230    0.983107  0.546212 -0.793673 -0.701679  0.591165
# f158        0.794230    0.983107  0.546212 -0.793673 -0.701679  0.591165
# f159       -0.460389   -0.300865 -0.813458  0.458766  0.491244 -0.280646
# f160       -0.460389   -0.300865 -0.813458  0.458766  0.491244 -0.280646
# f161        0.794230    0.983107  0.546212 -0.793673 -0.701679  0.591165
#
#                   f5        f6        f7        f8  ...      f152      f153  \
# ...

# %%
import seaborn as sns
sns.boxplot(data['f1'])
# Out:
# <Axes: >

# %% [markdown]
# In this report, we conducted an exploratory data analysis (EDA) and performed feature engineering on three datasets: customer information, financial transactions, and market trends. The EDA involved summarizing data statistics, visualizing distributions, handling missing values, and exploring correlations. Subsequently, feature engineering was implemented to enhance the datasets for modeling. This included creating new variables based on domain knowledge, encoding categorical variables, addressing outliers, and normalizing/standardizing numerical features. The insights gained from these processes are crucial for refining the datasets and preparing them for subsequent stages of modeling and analysis. The report sets the stage for further model development and evaluation, emphasizing the importance of a well-prepared dataset in the success of the overall data science project.
